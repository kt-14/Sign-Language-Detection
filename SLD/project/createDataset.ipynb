# %%
import numpy as np
import pandas as pd
import csv
import os
import cv2
import matplotlib.pyplot as plt
import mediapipe as mp

# %%
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

DATA_DIR = './data'

# %%
data = []
labels = []
for dir_ in os.listdir(DATA_DIR):
    for img_path in os.listdir(os.path.join(DATA_DIR, dir_)):
        data_aux = []

        x_ = []
        y_ = []

        img = cv2.imread(os.path.join(DATA_DIR, dir_, img_path))
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        results = hands.process(img_rgb)
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                
                # Get landmarks on the hand
                mp_drawing.draw_landmarks(
                    img_rgb,
                    hand_landmarks,
                    mp_hands.HAND_CONNECTIONS,
                    mp_drawing_styles.get_default_hand_landmarks_style(),
                    mp_drawing_styles.get_default_hand_connections_style()
                )
                
                for i in range(len(hand_landmarks.landmark)):
                    x = hand_landmarks.landmark[i].x
                    y = hand_landmarks.landmark[i].y

                    # data_aux.append(x)
                    # data_aux.append(y)
                    x_.append(x)
                    y_.append(y)

                for i in range(len(hand_landmarks.landmark)):
                    x = hand_landmarks.landmark[i].x
                    y = hand_landmarks.landmark[i].y
                    data_aux.append(x - min(x_))
                    data_aux.append(y - min(y_))

            data.append(data_aux)
            labels.append(dir_)
# Out:
# c:\SHRIVED\Games\Codes\ML\SLD\SLD_env\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
i = []
print(len(data))
print(len(labels))
for x in data:
    if len(x) > 42:
        print(len(x))
        i.append(data.index(x))
for _ in i:
    data.pop(_)
    labels.pop(_)
print(len(data))
for x in data:
    if len(x) > 42:
        print(len(x))
        i.append(data.index(x))
print(len(labels))
# Out:
# 2579
# 2579
# 2579
# 2579

# %%
df = pd.DataFrame(data=data,columns=[f'f{i}' for i in range(len(data[0]))])
df['class'] = list(map(int,labels))
df.head()
# Out:
#          f0        f1        f2        f3        f4        f5        f6  \
# 0  0.026926  0.211189  0.075056  0.179532  0.121865  0.118529  0.144809
# 1  0.028653  0.210765  0.076846  0.177180  0.122846  0.117856  0.144596
# 2  0.026404  0.212341  0.074268  0.180378  0.122163  0.119740  0.145107
# 3  0.026404  0.212341  0.074268  0.180378  0.122163  0.119740  0.145107
# 4  0.027747  0.209456  0.075612  0.176561  0.121689  0.116988  0.142969
#
#          f7        f8        f9  ...       f33  f34       f35       f36  \
# 0  0.059208  0.129693  0.013166  ...  0.124867  0.0  0.084490  0.009529
# 1  0.057485  0.129097  0.012203  ...  0.125772  0.0  0.083449  0.009630
# 2  0.060148  0.128698  0.014557  ...  0.126423  0.0  0.084410  0.010547
# 3  0.060148  0.128698  0.014557  ...  0.126423  0.0  0.084410  0.010547
# 4  0.058841  0.125906  0.015016  ...  0.124149  0.0  0.085814  0.007954
#
#         f37       f38       f39       f40       f41  class
# 0  0.057020  0.022645  0.103716  0.030495  0.136325      0
# 1  0.056307  0.023633  0.102898  0.031943  0.135311      0
# 2  0.060463  0.022247  0.108153  0.029980  0.141910      0
# 3  0.060463  0.022247  0.108153  0.029980  0.141910      0
# 4  0.057932  0.018551  0.105050  0.027027  0.139705      0
#
# [5 rows x 43 columns]

# %%
df.isnull().sum()
# Out:
# f0       0
# f1       0
# f2       0
# f3       0
# f4       0
# f5       0
# f6       0
# f7       0
# f8       0
# f9       0
# f10      0
# f11      0
# f12      0
# f13      0
# f14      0
# f15      0
# f16      0
# f17      0
# f18      0
# f19      0
# f20      0
# f21      0
# f22      0
# f23      0
# f24      0
# f25      0
# f26      0
# f27      0
# f28      0
# f29      0
# f30      0
# f31      0
# f32      0
# f33      0
# f34      0
# f35      0
# f36      0
# f37      0
# f38      0
# f39      0
# f40      0
# f41      0
# class    0
# dtype: int64

# %%
df.to_csv('dataset.csv')
